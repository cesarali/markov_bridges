# %%
import os
import sys
import torch
import numpy as np
from torch import matmul as m
from matplotlib import pyplot as plt
from sdes import SDE,ConstantDiffusion,TwoDimensionalSynDrift,DoubleWellDrift,MaxDiffusion,LinearDrift1D
from torch.autograd.functional import jacobian

from torch.distributions import MultivariateNormal

sys.path.insert(0,".")

from gpytorch.kernels import (
    RBFKernel, 
    ScaleKernel,
    PolynomialKernel
)

from utils import define_grid_ranges,define_mesh_points
from gps import MultivariateNormal,white_noise_kernel
from sde_sparse_gp import SparseGPSDE
from sde_gp_em import maximization, OU

# %% [markdown]
# ## Generate SDEs

# %%
dt = 0.002
number_of_steps = 10000
num_paths = 3
sigma = 1.

#x_0 = torch.rand((1,)).unsqueeze(-1)
#real_drift = LinearDrift1D(a=4.)
#diffusion = MaxDiffusion()
#diffusion = ConstantDiffusion(sigma=sigma)

x_0 = torch.rand((1,)).unsqueeze(-1)
real_drift = DoubleWellDrift(a=4.,b=4.)
diffusion = MaxDiffusion()
#diffusion = ConstantDiffusion(sigma=sigma)

#x_0 = torch.rand((2,)).unsqueeze(0)
#real_drift = TwoDimensionalSynDrift()
#diffusion = ConstantDiffusion(sigma=sigma)

sde = SDE(real_drift,diffusion,dt=dt)
dense_path_realization = sde.simulate(x_0, number_of_steps, num_paths=num_paths)
dense_path_realization = dense_path_realization[0,:,:]

# %%
#=============================================
#DEFINE SPARSE OBSERVATIONS
#=============================================
num_dense_steps_in_bridge = 10
number_of_steps = dense_path_realization.size(0)
dense_time = torch.arange(0,number_of_steps)*dt
max_time = number_of_steps*dt
observation_index = range(0,number_of_steps,num_dense_steps_in_bridge)
sparse_observation_time = dense_time[observation_index]
sparse_observations = dense_path_realization[observation_index]
plt.figure(figsize=(10,2))
plt.title(f"Number of Points {sparse_observation_time.size(0)}")
plt.plot(dense_time,dense_path_realization[:,0],"b-")
plt.plot(sparse_observation_time,sparse_observations[:,0],"ro")
plt.show()

# %% [markdown]
# # Complete EM Loop

# %%
nmc_x = 100
nmc_t = 300
num_inducing_points = 10
num_evaluation_points = 1000
dimensions = sparse_observations.size(1)
EPSILON = 1e-4
kernels = [PolynomialKernel(power=4)]
kernels_parameters = [(.5,1.),(1.,1.)]

do = True
if do:
    number_of_em_steps = 10

    #define ranges where to plot
    ranges_ = define_grid_ranges(dense_path_realization,ignore_percentatge=0.02)
    evaluation_points = define_mesh_points(total_points=num_evaluation_points,n_dims=dimensions,ranges=ranges_)

    # defines times to calculate the time integral
    mc_times = torch.rand((nmc_t,))*sparse_observation_time.max() # random times
    full_times = torch.linspace(0.,max_time-2*dt,200) # times on grid
    mc_times = full_times

    # if avaliable obtains the real drift for error estimation
    real_drift_ = real_drift(evaluation_points)

    # drift estimation as sparse gps approximation
    sparse_gp_sde = SparseGPSDE(sparse_observations,
                                dt=dt,
                                kernels=kernels,
                                #kernel_parameters=kernels_parameters,
                                num_inducing_points=num_inducing_points)
    sparse_gp_sde.inference(diffusion)
    drift_from_sparse_gp = sparse_gp_sde(evaluation_points)

    # do not accumulate grdients
    for kernel in sparse_gp_sde.kernels:
        kernel.eval()
        
    # EM loop
    # selects starting drift as sparse gps approximation
    current_drift = sparse_gp_sde
    for em_step_index in range(number_of_em_steps):
        print(f"EM step {em_step_index}")
        # Expectation Step 
        # samples monte carlo points from the ou bridge
        # by using previous estimate as drift 
        monte_carlo_points_,m_t,C_t,A_x,g_x = OU(mc_times,
                                                sparse_observation_time,
                                                sparse_observations,
                                                diffusion,
                                                drift=current_drift,
                                                nmc_x=nmc_x,
                                                evidence=False,
                                                EPSILON=EPSILON)
        print("Sample")
        # Maximixation Step
        def current_drift(x):
            F_x = maximization(x,
                               monte_carlo_points_,
                               sparse_gp_sde.inducing_points,
                               sparse_gp_sde.kernels,
                               A_x,
                               g_x,
                               diffusion,
                               option_2=True,
                               EPSILON=EPSILON)
            return F_x
        
        F_x = current_drift(evaluation_points)

        # Plot
        plt.plot(evaluation_points,F_x[:,0].detach().numpy(),label="m estimation")
        plt.plot(evaluation_points,real_drift_[:,0].detach().numpy(),"r-",label="real")
        #plt.plot(evaluation_points,drift_from_sparse_gp[:,0].detach().numpy(),label="sparse_approx")
        plt.legend(loc="best")
        plt.savefig("em_step_{0}.png".format(em_step_index))
        plt.show()
# Out:
# EM step 0
# Sample
# EM step 1
# Jittering: adding small epsilon to the diagonal of matrices where needed
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[12], line 47
#      43 print(f"EM step {em_step_index}")
#      44 # Expectation Step
#      45 # samples monte carlo points from the ou bridge
#      46 # by using previous estimate as drift
# ---> 47 monte_carlo_points_,m_t,C_t,A_x,g_x = OU(mc_times,
#      48                                         sparse_observation_time,
#      49                                         sparse_observations,
#      50                                         diffusion,
#      51                                         drift=current_drift,
#      52                                         nmc_x=nmc_x,
#      53                                         evidence=False,
#      54                                         EPSILON=EPSILON)
#      55 print("Sample")
#      56 # Maximixation Step
#
# File c:\Users\cesar\Desktop\Projects\DiffusiveGenerativeModelling\OurCodes\markov_bridges\notebooks\models\Misselaneous\.\sde_gp_em.py:189, in OU(mc_times, observation_times, observations, diffusion, drift, nmc_x, evidence, EPSILON)
#     186 else:
#     187     #m_t = torch.clamp(m_t,1e-5)
#     188     C_t = torch.clamp(C_t,1e-5)
# --> 189     q_t = Normal(m_t.squeeze(),C_t.squeeze())
#     190     monte_carlo_points = q_t.sample((nmc_x,)).unsqueeze(-1)
#     192 # AVERAGE DRIFT
#
# File c:\Users\cesar\anaconda4\envs\rate_matching\lib\site-packages\torch\distributions\normal.py:56, in Normal.__init__(self, loc, scale, validate_args)
#      54 else:
#      55     batch_shape = self.loc.size()
# ---> 56 super().__init__(batch_shape, validate_args=validate_args)
#
# File c:\Users\cesar\anaconda4\envs\rate_matching\lib\site-packages\torch\distributions\distribution.py:68, in Distribution.__init__(self, batch_shape, event_shape, validate_args)
#      66         valid = constraint.check(value)
#      67         if not valid.all():
# ---> 68             raise ValueError(
#      69                 f"Expected parameter {param} "
#      70                 f"({type(value).__name__} of shape {tuple(value.shape)}) "
#      71                 f"of distribution {repr(self)} "
#      72                 f"to satisfy the constraint {repr(constraint)}, "
#      73                 f"but found invalid values:\n{value}"
#      74             )
#      75 super().__init__()
#
# ValueError: Expected parameter loc (Tensor of shape (200,)) of distribution Normal(loc: torch.Size([200]), scale: torch.Size([200])) to satisfy the constraint Real(), but found invalid values:
# tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan, nan,
#         nan, nan, nan, nan, nan, nan, nan, nan], grad_fn=<SqueezeBackward0>)
